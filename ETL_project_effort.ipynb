# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2

# %%
csv2_file = "Resources/symbols_valid_meta.csv"
svm_data_df = pd.read_csv(csv2_file)
svm_data_df.head()
# Out:
#   Nasdaq Traded Symbol                                      Security Name  \
# 0             Y      A            Agilent Technologies, Inc. Common Stock
# 1             Y     AA                    Alcoa Corporation Common Stock
# 2             Y   AAAU                       Perth Mint Physical Gold ETF
# 3             Y   AACG  ATA Creativity Global - American Depositary Sh...
# 4             Y   AADR                AdvisorShares Dorsey Wright ADR ETF
#
#   Listing Exchange Market Category ETF  Round Lot Size Test Issue  \
# 0                N                   N           100.0          N
# 1                N                   N           100.0          N
# 2                P                   Y           100.0          N
# 3                Q               G   N           100.0          N
# 4                P                   Y           100.0          N
#
#   Financial Status CQS Symbol NASDAQ Symbol NextShares
# 0              NaN          A             A          N
# 1              NaN         AA            AA          N
# 2              NaN       AAAU          AAAU          N
# 3                N        NaN          AACG          N
# 4              NaN       AADR          AADR          N

# %%
csv_file="Resources/IPODataFUll.csv"
ipod_data_df = pd.read_csv(csv_file,encoding='ISO-8859-1')
ipod_data_df.head()
# Out:
# C:\Users\supra\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (1342,1425,1432,1543,1546,1549,1551,1552,1553,1562,1587,1588,1605,1608,1615,1619,1620,1621,1622,1629,1630,1632,1633,1640,1641,1642,1643,1644,1646) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   Symbol  DaysBetterThanSP  daysProfit daysProfitGrouped  exactDiffernce  \
# 0      A               122         249              200+             NaN
# 1    AAC               131         262              200+           232.0
# 2   AAOI               125         262              200+          6054.0
# 3    AAP               128         261              200+             NaN
# 4    AAT               123         127         100 - 149           181.0
#
#    Year  Month  Day  dayOfWeek  closeDay0  ...  usableCEOAge  usableCEOGender  \
# 0  1999     11   18          3    28.6358  ...         Blank            Blank
# 1  2014     10    2          3    18.5000  ...       40 - 49             male
# 2  2013      9   26          3     9.9600  ...         Blank            Blank
# 3  2001     11   29          3    13.9000  ...         Blank            Blank
# 4  2011      1   13          3    21.2500  ...         Blank            Blank
#
#    usablePresidentAge  usablePresidentGender  FoundingDateGrouped  \
# 0               Blank                  Blank          1951 - 2000
# 1               Blank                  Blank       2011 - present
# 2               Blank                  Blank          1951 - 2000
# 3               Blank                  Blank          1901 - 1950
# 4               Blank                  Blank          2001 - 2010
#
#    yearDifferenceGrouped  Profitable  Safe  HomeRunDay  HomeRun
# 0                Unknown           1     0        77.0        1
# 1                Unknown           1     1         NaN        0
# 2                Unknown           1     0         NaN        0
# 3                Unknown           1     0         NaN        0
# 4                Unknown           0     0         NaN        0
#
# [5 rows x 1664 columns]

# %%
list(ipod_data_df.columns)
# Out:
# ['Symbol',
#  'DaysBetterThanSP',
#  'daysProfit',
#  'daysProfitGrouped',
#  'exactDiffernce',
#  'Year',
#  'Month',
#  'Day',
#  'dayOfWeek',
#  'closeDay0',
#  'highDay0',
#  'openDay0',
#  'lowDay0',
#  'volumeDay0',
#  'closeDay1',
#  'highDay1',
#  'openDay1',
#  'lowDay1',
#  'volumeDay1',
#  'closeDay2',
#  'highDay2',
#  'openDay2',
#  'lowDay2',
#  'volumeDay2',
#  'closeDay3',
#  'highDay3',
#  'openDay3',
#  'lowDay3',
#  'volumeDay3',
#  'closeDay4',
#  'highDay4',
#  'openDay4',
#  'lowDay4',
#  'volumeDay4',
#  'closeDay5',
#  'highDay5',
#  'openDay5',
#  'lowDay5',
#  'volumeDay5',
#  'closeDay6',
#  'highDay6',
#  'openDay6',
#  'lowDay6',
#  'volumeDay6',
#  'closeDay7',
#  'highDay7',
#  'openDay7',
#  'lowDay7',
#  'volumeDay7',
#  'closeDay8',
#  'highDay8',
#  'openDay8',
#  'lowDay8',
#  'volumeDay8',
#  'closeDay9',
#  'highDay9',
#  'openDay9',
#  'lowDay9',
#  'volumeDay9',
#  'closeDay10',
#  'highDay10',
#  'openDay10',
#  'lowDay10',
#  'volumeDay10',
#  'closeDay11',
#  'highDay11',
#  'openDay11',
#  'lowDay11',
#  'volumeDay11',
#  'closeDay12',
#  'highDay12',
#  'openDay12',
#  'lowDay12',
#  'volumeDay12',
#  'closeDay13',
#  'highDay13',
#  'openDay13',
#  'lowDay13',
#  'volumeDay13',
#  'closeDay14',
#  'highDay14',
#  'openDay14',
#  'lowDay14',
#  'volumeDay14',
#  'closeDay15',
#  'highDay15',
#  'openDay15',
#  'lowDay15',
#  'volumeDay15',
#  'closeDay16',
#  'highDay16',
#  'openDay16',
#  'lowDay16',
#  'volumeDay16',
#  'closeDay17',
#  'highDay17',
#  'openDay17',
#  'lowDay17',
#  'volumeDay17',
#  'closeDay18',
#  'highDay18',
#  'openDay18',
#  'lowDay18',
#  'volumeDay18',
#  'closeDay19',
#  'highDay19',
#  'openDay19',
#  'lowDay19',
#  'volumeDay19',
#  'closeDay20',
#  'highDay20',
#  'openDay20',
#  'lowDay20',
#  'volumeDay20',
#  'closeDay21',
#  'highDay21',
#  'openDay21',
#  'lowDay21',
#  'volumeDay21',
#  'closeDay22',
#  'highDay22',
#  'openDay22',
#  'lowDay22',
#  'volumeDay22',
#  'closeDay23',
#  'highDay23',
#  'openDay23',
#  'lowDay23',
#  'volumeDay23',
#  'closeDay24',
#  'highDay24',
#  'openDay24',
#  'lowDay24',
#  'volumeDay24',
#  'closeDay25',
#  'highDay25',
#  'openDay25',
#  'lowDay25',
#  'volumeDay25',
#  'closeDay26',
#  'highDay26',
#  'openDay26',
#  'lowDay26',
#  'volumeDay26',
#  'closeDay27',
#  'highDay27',
#  'openDay27',
#  'lowDay27',
#  'volumeDay27',
#  'closeDay28',
#  'highDay28',
#  'openDay28',
#  'lowDay28',
#  'volumeDay28',
#  'closeDay29',
#  'highDay29',
#  'openDay29',
#  'lowDay29',
#  'volumeDay29',
#  'closeDay30',
#  'highDay30',
#  'openDay30',
#  'lowDay30',
#  'volumeDay30',
#  'closeDay31',
#  'highDay31',
#  'openDay31',
#  'lowDay31',
#  'volumeDay31',
#  'closeDay32',
#  'highDay32',
#  'openDay32',
#  'lowDay32',
#  'volumeDay32',
#  'closeDay33',
#  'highDay33',
#  'openDay33',
#  'lowDay33',
#  'volumeDay33',
#  'closeDay34',
#  'highDay34',
#  'openDay34',
#  'lowDay34',
#  'volumeDay34',
#  'closeDay35',
#  'highDay35',
#  'openDay35',
#  'lowDay35',
#  'volumeDay35',
#  'closeDay36',
#  'highDay36',
#  'openDay36',
#  'lowDay36',
#  'volumeDay36',
#  'closeDay37',
#  'highDay37',
#  'openDay37',
#  'lowDay37',
#  'volumeDay37',
#  'closeDay38',
#  'highDay38',
#  'openDay38',
#  'lowDay38',
#  'volumeDay38',
#  'closeDay39',
#  'highDay39',
#  'openDay39',
#  'lowDay39',
#  'volumeDay39',
#  'closeDay40',
#  'highDay40',
#  'openDay40',
#  'lowDay40',
#  'volumeDay40',
#  'closeDay41',
#  'highDay41',
#  'openDay41',
#  'lowDay41',
#  'volumeDay41',
#  'closeDay42',
#  'highDay42',
#  'openDay42',
#  'lowDay42',
#  'volumeDay42',
#  'closeDay43',
#  'highDay43',
#  'openDay43',
#  'lowDay43',
#  'volumeDay43',
#  'closeDay44',
#  'highDay44',
#  'openDay44',
#  'lowDay44',
#  'volumeDay44',
#  'closeDay45',
#  'highDay45',
#  'openDay45',
#  'lowDay45',
#  'volumeDay45',
#  'closeDay46',
#  'highDay46',
#  'openDay46',
#  'lowDay46',
#  'volumeDay46',
#  'closeDay47',
#  'highDay47',
#  'openDay47',
#  'lowDay47',
#  'volumeDay47',
#  'closeDay48',
#  'highDay48',
#  'openDay48',
#  'lowDay48',
#  'volumeDay48',
#  'closeDay49',
#  'highDay49',
#  'openDay49',
#  'lowDay49',
#  'volumeDay49',
#  'closeDay50',
#  'highDay50',
#  'openDay50',
#  'lowDay50',
#  'volumeDay50',
#  'closeDay51',
#  'highDay51',
#  'openDay51',
#  'lowDay51',
#  'volumeDay51',
#  'closeDay52',
#  'highDay52',
#  'openDay52',
#  'lowDay52',
#  'volumeDay52',
#  'closeDay53',
#  'highDay53',
#  'openDay53',
#  'lowDay53',
#  'volumeDay53',
#  'closeDay54',
#  'highDay54',
#  'openDay54',
#  'lowDay54',
#  'volumeDay54',
#  'closeDay55',
#  'highDay55',
#  'openDay55',
#  'lowDay55',
#  'volumeDay55',
#  'closeDay56',
#  'highDay56',
#  'openDay56',
#  'lowDay56',
#  'volumeDay56',
#  'closeDay57',
#  'highDay57',
#  'openDay57',
#  'lowDay57',
#  'volumeDay57',
#  'closeDay58',
#  'highDay58',
#  'openDay58',
#  'lowDay58',
#  'volumeDay58',
#  'closeDay59',
#  'highDay59',
#  'openDay59',
#  'lowDay59',
#  'volumeDay59',
#  'closeDay60',
#  'highDay60',
#  'openDay60',
#  'lowDay60',
#  'volumeDay60',
#  'closeDay61',
#  'highDay61',
#  'openDay61',
#  'lowDay61',
#  'volumeDay61',
#  'closeDay62',
#  'highDay62',
#  'openDay62',
#  'lowDay62',
#  'volumeDay62',
#  'closeDay63',
#  'highDay63',
#  'openDay63',
#  'lowDay63',
#  'volumeDay63',
#  'closeDay64',
#  'highDay64',
#  'openDay64',
#  'lowDay64',
#  'volumeDay64',
#  'closeDay65',
#  'highDay65',
#  'openDay65',
#  'lowDay65',
#  'volumeDay65',
#  'closeDay66',
#  'highDay66',
#  'openDay66',
#  'lowDay66',
#  'volumeDay66',
#  'closeDay67',
#  'highDay67',
#  'openDay67',
#  'lowDay67',
#  'volumeDay67',
#  'closeDay68',
#  'highDay68',
#  'openDay68',
#  'lowDay68',
#  'volumeDay68',
#  'closeDay69',
#  'highDay69',
#  'openDay69',
#  'lowDay69',
#  'volumeDay69',
#  'closeDay70',
#  'highDay70',
#  'openDay70',
#  'lowDay70',
#  'volumeDay70',
#  'closeDay71',
#  'highDay71',
#  'openDay71',
#  'lowDay71',
#  'volumeDay71',
#  'closeDay72',
#  'highDay72',
#  'openDay72',
#  'lowDay72',
#  'volumeDay72',
#  'closeDay73',
#  'highDay73',
#  'openDay73',
#  'lowDay73',
#  'volumeDay73',
#  'closeDay74',
#  'highDay74',
#  'openDay74',
#  'lowDay74',
#  'volumeDay74',
#  'closeDay75',
#  'highDay75',
#  'openDay75',
#  'lowDay75',
#  'volumeDay75',
#  'closeDay76',
#  'highDay76',
#  'openDay76',
#  'lowDay76',
#  'volumeDay76',
#  'closeDay77',
#  'highDay77',
#  'openDay77',
#  'lowDay77',
#  'volumeDay77',
#  'closeDay78',
#  'highDay78',
#  'openDay78',
#  'lowDay78',
#  'volumeDay78',
#  'closeDay79',
#  'highDay79',
#  'openDay79',
#  'lowDay79',
#  'volumeDay79',
#  'closeDay80',
#  'highDay80',
#  'openDay80',
#  'lowDay80',
#  'volumeDay80',
#  'closeDay81',
#  'highDay81',
#  'openDay81',
#  'lowDay81',
#  'volumeDay81',
#  'closeDay82',
#  'highDay82',
#  'openDay82',
#  'lowDay82',
#  'volumeDay82',
#  'closeDay83',
#  'highDay83',
#  'openDay83',
#  'lowDay83',
#  'volumeDay83',
#  'closeDay84',
#  'highDay84',
#  'openDay84',
#  'lowDay84',
#  'volumeDay84',
#  'closeDay85',
#  'highDay85',
#  'openDay85',
#  'lowDay85',
#  'volumeDay85',
#  'closeDay86',
#  'highDay86',
#  'openDay86',
#  'lowDay86',
#  'volumeDay86',
#  'closeDay87',
#  'highDay87',
#  'openDay87',
#  'lowDay87',
#  'volumeDay87',
#  'closeDay88',
#  'highDay88',
#  'openDay88',
#  'lowDay88',
#  'volumeDay88',
#  'closeDay89',
#  'highDay89',
#  'openDay89',
#  'lowDay89',
#  'volumeDay89',
#  'closeDay90',
#  'highDay90',
#  'openDay90',
#  'lowDay90',
#  'volumeDay90',
#  'closeDay91',
#  'highDay91',
#  'openDay91',
#  'lowDay91',
#  'volumeDay91',
#  'closeDay92',
#  'highDay92',
#  'openDay92',
#  'lowDay92',
#  'volumeDay92',
#  'closeDay93',
#  'highDay93',
#  'openDay93',
#  'lowDay93',
#  'volumeDay93',
#  'closeDay94',
#  'highDay94',
#  'openDay94',
#  'lowDay94',
#  'volumeDay94',
#  'closeDay95',
#  'highDay95',
#  'openDay95',
#  'lowDay95',
#  'volumeDay95',
#  'closeDay96',
#  'highDay96',
#  'openDay96',
#  'lowDay96',
#  'volumeDay96',
#  'closeDay97',
#  'highDay97',
#  'openDay97',
#  'lowDay97',
#  'volumeDay97',
#  'closeDay98',
#  'highDay98',
#  'openDay98',
#  'lowDay98',
#  'volumeDay98',
#  'closeDay99',
#  'highDay99',
#  'openDay99',
#  'lowDay99',
#  'volumeDay99',
#  'closeDay100',
#  'highDay100',
#  'openDay100',
#  'lowDay100',
#  'volumeDay100',
#  'closeDay101',
#  'highDay101',
#  'openDay101',
#  'lowDay101',
#  'volumeDay101',
#  'closeDay102',
#  'highDay102',
#  'openDay102',
#  'lowDay102',
#  'volumeDay102',
#  'closeDay103',
#  'highDay103',
#  'openDay103',
#  'lowDay103',
#  'volumeDay103',
#  'closeDay104',
#  'highDay104',
#  'openDay104',
#  'lowDay104',
#  'volumeDay104',
#  'closeDay105',
#  'highDay105',
#  'openDay105',
#  'lowDay105',
#  'volumeDay105',
#  'closeDay106',
#  'highDay106',
#  'openDay106',
#  'lowDay106',
#  'volumeDay106',
#  'closeDay107',
#  'highDay107',
#  'openDay107',
#  'lowDay107',
#  'volumeDay107',
#  'closeDay108',
#  'highDay108',
#  'openDay108',
#  'lowDay108',
#  'volumeDay108',
#  'closeDay109',
#  'highDay109',
#  'openDay109',
#  'lowDay109',
#  'volumeDay109',
#  'closeDay110',
#  'highDay110',
#  'openDay110',
#  'lowDay110',
#  'volumeDay110',
#  'closeDay111',
#  'highDay111',
#  'openDay111',
#  'lowDay111',
#  'volumeDay111',
#  'closeDay112',
#  'highDay112',
#  'openDay112',
#  'lowDay112',
#  'volumeDay112',
#  'closeDay113',
#  'highDay113',
#  'openDay113',
#  'lowDay113',
#  'volumeDay113',
#  'closeDay114',
#  'highDay114',
#  'openDay114',
#  'lowDay114',
#  'volumeDay114',
#  'closeDay115',
#  'highDay115',
#  'openDay115',
#  'lowDay115',
#  'volumeDay115',
#  'closeDay116',
#  'highDay116',
#  'openDay116',
#  'lowDay116',
#  'volumeDay116',
#  'closeDay117',
#  'highDay117',
#  'openDay117',
#  'lowDay117',
#  'volumeDay117',
#  'closeDay118',
#  'highDay118',
#  'openDay118',
#  'lowDay118',
#  'volumeDay118',
#  'closeDay119',
#  'highDay119',
#  'openDay119',
#  'lowDay119',
#  'volumeDay119',
#  'closeDay120',
#  'highDay120',
#  'openDay120',
#  'lowDay120',
#  'volumeDay120',
#  'closeDay121',
#  'highDay121',
#  'openDay121',
#  'lowDay121',
#  'volumeDay121',
#  'closeDay122',
#  'highDay122',
#  'openDay122',
#  'lowDay122',
#  'volumeDay122',
#  'closeDay123',
#  'highDay123',
#  'openDay123',
#  'lowDay123',
#  'volumeDay123',
#  'closeDay124',
#  'highDay124',
#  'openDay124',
#  'lowDay124',
#  'volumeDay124',
#  'closeDay125',
#  'highDay125',
#  'openDay125',
#  'lowDay125',
#  'volumeDay125',
#  'closeDay126',
#  'highDay126',
#  'openDay126',
#  'lowDay126',
#  'volumeDay126',
#  'closeDay127',
#  'highDay127',
#  'openDay127',
#  'lowDay127',
#  'volumeDay127',
#  'closeDay128',
#  'highDay128',
#  'openDay128',
#  'lowDay128',
#  'volumeDay128',
#  'closeDay129',
#  'highDay129',
#  'openDay129',
#  'lowDay129',
#  'volumeDay129',
#  'closeDay130',
#  'highDay130',
#  'openDay130',
#  'lowDay130',
#  'volumeDay130',
#  'closeDay131',
#  'highDay131',
#  'openDay131',
#  'lowDay131',
#  'volumeDay131',
#  'closeDay132',
#  'highDay132',
#  'openDay132',
#  'lowDay132',
#  'volumeDay132',
#  'closeDay133',
#  'highDay133',
#  'openDay133',
#  'lowDay133',
#  'volumeDay133',
#  'closeDay134',
#  'highDay134',
#  'openDay134',
#  'lowDay134',
#  'volumeDay134',
#  'closeDay135',
#  'highDay135',
#  'openDay135',
#  'lowDay135',
#  'volumeDay135',
#  'closeDay136',
#  'highDay136',
#  'openDay136',
#  'lowDay136',
#  'volumeDay136',
#  'closeDay137',
#  'highDay137',
#  'openDay137',
#  'lowDay137',
#  'volumeDay137',
#  'closeDay138',
#  'highDay138',
#  'openDay138',
#  'lowDay138',
#  'volumeDay138',
#  'closeDay139',
#  'highDay139',
#  'openDay139',
#  'lowDay139',
#  'volumeDay139',
#  'closeDay140',
#  'highDay140',
#  'openDay140',
#  'lowDay140',
#  'volumeDay140',
#  'closeDay141',
#  'highDay141',
#  'openDay141',
#  'lowDay141',
#  'volumeDay141',
#  'closeDay142',
#  'highDay142',
#  'openDay142',
#  'lowDay142',
#  'volumeDay142',
#  'closeDay143',
#  'highDay143',
#  'openDay143',
#  'lowDay143',
#  'volumeDay143',
#  'closeDay144',
#  'highDay144',
#  'openDay144',
#  'lowDay144',
#  'volumeDay144',
#  'closeDay145',
#  'highDay145',
#  'openDay145',
#  'lowDay145',
#  'volumeDay145',
#  'closeDay146',
#  'highDay146',
#  'openDay146',
#  'lowDay146',
#  'volumeDay146',
#  'closeDay147',
#  'highDay147',
#  'openDay147',
#  'lowDay147',
#  'volumeDay147',
#  'closeDay148',
#  'highDay148',
#  'openDay148',
#  'lowDay148',
#  'volumeDay148',
#  'closeDay149',
#  'highDay149',
#  'openDay149',
#  'lowDay149',
#  'volumeDay149',
#  'closeDay150',
#  'highDay150',
#  'openDay150',
#  'lowDay150',
#  'volumeDay150',
#  'closeDay151',
#  'highDay151',
#  'openDay151',
#  'lowDay151',
#  'volumeDay151',
#  'closeDay152',
#  'highDay152',
#  'openDay152',
#  'lowDay152',
#  'volumeDay152',
#  'closeDay153',
#  'highDay153',
#  'openDay153',
#  'lowDay153',
#  'volumeDay153',
#  'closeDay154',
#  'highDay154',
#  'openDay154',
#  'lowDay154',
#  'volumeDay154',
#  'closeDay155',
#  'highDay155',
#  'openDay155',
#  'lowDay155',
#  'volumeDay155',
#  'closeDay156',
#  'highDay156',
#  'openDay156',
#  'lowDay156',
#  'volumeDay156',
#  'closeDay157',
#  'highDay157',
#  'openDay157',
#  'lowDay157',
#  'volumeDay157',
#  'closeDay158',
#  'highDay158',
#  'openDay158',
#  'lowDay158',
#  'volumeDay158',
#  'closeDay159',
#  'highDay159',
#  'openDay159',
#  'lowDay159',
#  'volumeDay159',
#  'closeDay160',
#  'highDay160',
#  'openDay160',
#  'lowDay160',
#  'volumeDay160',
#  'closeDay161',
#  'highDay161',
#  'openDay161',
#  'lowDay161',
#  'volumeDay161',
#  'closeDay162',
#  'highDay162',
#  'openDay162',
#  'lowDay162',
#  'volumeDay162',
#  'closeDay163',
#  'highDay163',
#  'openDay163',
#  'lowDay163',
#  'volumeDay163',
#  'closeDay164',
#  'highDay164',
#  'openDay164',
#  'lowDay164',
#  'volumeDay164',
#  'closeDay165',
#  'highDay165',
#  'openDay165',
#  'lowDay165',
#  'volumeDay165',
#  'closeDay166',
#  'highDay166',
#  'openDay166',
#  'lowDay166',
#  'volumeDay166',
#  'closeDay167',
#  'highDay167',
#  'openDay167',
#  'lowDay167',
#  'volumeDay167',
#  'closeDay168',
#  'highDay168',
#  'openDay168',
#  'lowDay168',
#  'volumeDay168',
#  'closeDay169',
#  'highDay169',
#  'openDay169',
#  'lowDay169',
#  'volumeDay169',
#  'closeDay170',
#  'highDay170',
#  'openDay170',
#  'lowDay170',
#  'volumeDay170',
#  'closeDay171',
#  'highDay171',
#  'openDay171',
#  'lowDay171',
#  'volumeDay171',
#  'closeDay172',
#  'highDay172',
#  'openDay172',
#  'lowDay172',
#  'volumeDay172',
#  'closeDay173',
#  'highDay173',
#  'openDay173',
#  'lowDay173',
#  'volumeDay173',
#  'closeDay174',
#  'highDay174',
#  'openDay174',
#  'lowDay174',
#  'volumeDay174',
#  'closeDay175',
#  'highDay175',
#  'openDay175',
#  'lowDay175',
#  'volumeDay175',
#  'closeDay176',
#  'highDay176',
#  'openDay176',
#  'lowDay176',
#  'volumeDay176',
#  'closeDay177',
#  'highDay177',
#  'openDay177',
#  'lowDay177',
#  'volumeDay177',
#  'closeDay178',
#  'highDay178',
#  'openDay178',
#  'lowDay178',
#  'volumeDay178',
#  'closeDay179',
#  'highDay179',
#  'openDay179',
#  'lowDay179',
#  'volumeDay179',
#  'closeDay180',
#  'highDay180',
#  'openDay180',
#  'lowDay180',
#  'volumeDay180',
#  'closeDay181',
#  'highDay181',
#  'openDay181',
#  'lowDay181',
#  'volumeDay181',
#  'closeDay182',
#  'highDay182',
#  'openDay182',
#  'lowDay182',
#  'volumeDay182',
#  'closeDay183',
#  'highDay183',
#  'openDay183',
#  'lowDay183',
#  'volumeDay183',
#  'closeDay184',
#  'highDay184',
#  'openDay184',
#  'lowDay184',
#  'volumeDay184',
#  'closeDay185',
#  'highDay185',
#  'openDay185',
#  'lowDay185',
#  'volumeDay185',
#  'closeDay186',
#  'highDay186',
#  'openDay186',
#  'lowDay186',
#  'volumeDay186',
#  'closeDay187',
#  'highDay187',
#  'openDay187',
#  'lowDay187',
#  'volumeDay187',
#  'closeDay188',
#  'highDay188',
#  'openDay188',
#  'lowDay188',
#  'volumeDay188',
#  'closeDay189',
#  'highDay189',
#  'openDay189',
#  'lowDay189',
#  'volumeDay189',
#  'closeDay190',
#  'highDay190',
#  'openDay190',
#  'lowDay190',
#  'volumeDay190',
#  'closeDay191',
#  'highDay191',
#  'openDay191',
#  'lowDay191',
#  'volumeDay191',
#  'closeDay192',
#  'highDay192',
#  'openDay192',
#  'lowDay192',
#  'volumeDay192',
#  'closeDay193',
#  'highDay193',
#  'openDay193',
#  'lowDay193',
#  'volumeDay193',
#  'closeDay194',
#  'highDay194',
#  'openDay194',
#  'lowDay194',
#  'volumeDay194',
#  'closeDay195',
#  'highDay195',
#  'openDay195',
#  'lowDay195',
#  'volumeDay195',
#  'closeDay196',
#  'highDay196',
#  'openDay196',
#  'lowDay196',
#  'volumeDay196',
#  'closeDay197',
#  'highDay197',
#  'openDay197',
#  'lowDay197',
#  'volumeDay197',
#  'closeDay198',
#  ...]

# %%
list(svm_data_df.columns)
# Out:
# ['Nasdaq Traded',
#  'Symbol',
#  'Security Name',
#  'Listing Exchange',
#  'Market Category',
#  'ETF',
#  'Round Lot Size',
#  'Test Issue',
#  'Financial Status',
#  'CQS Symbol',
#  'NASDAQ Symbol',
#  'NextShares']

# %%
info_svm_data_df=svm_data_df [["Symbol","Nasdaq Traded","Security Name","CQS Symbol","NASDAQ Symbol"]]
info_svm_data_df.head()
# Out:
#   Symbol Nasdaq Traded                                      Security Name  \
# 0      A             Y            Agilent Technologies, Inc. Common Stock
# 1     AA             Y                    Alcoa Corporation Common Stock
# 2   AAAU             Y                       Perth Mint Physical Gold ETF
# 3   AACG             Y  ATA Creativity Global - American Depositary Sh...
# 4   AADR             Y                AdvisorShares Dorsey Wright ADR ETF
#
#   CQS Symbol NASDAQ Symbol
# 0          A             A
# 1         AA            AA
# 2       AAAU          AAAU
# 3        NaN          AACG
# 4       AADR          AADR

# %%
info_ipod_data_df=ipod_data_df[["Symbol","Name","Sector","Industry","CEOName","PresidentName"]]
info_ipod_data_df.head()
# Out:
#   Symbol                           Name             Sector  \
# 0      A     Agilent Technologies, Inc.      Capital Goods
# 1    AAC             AAC Holdings, Inc.        Health Care
# 2   AAOI  Applied Optoelectronics, Inc.         Technology
# 3    AAP         Advance Auto Parts Inc  Consumer Services
# 4    AAT    American Assets Trust, Inc.  Consumer Services
#
#                                            Industry             CEOName  \
# 0  Biotechnology: Laboratory Analytical Instruments    Michael McMullen
# 1                              Medical Specialities  Michael Cartwright
# 2                                    Semiconductors     Chih-Hsiang Lin
# 3                            Other Specialty Stores        Thomas Greco
# 4                     Real Estate Investment Trusts         Ernest Rady
#
#       PresidentName
# 0  Michael McMullen
# 1     Michael Nanko
# 2   Chih-Hsiang Lin
# 3      Thomas Greco
# 4       Ernest Rady

# %%
con_string = "postgres:072715@localhost:5432/Stocks"
engine=create_engine(f'postgresql://{con_string}')

# %%
engine.table_names()
# Out:
# ['IPODataFull', 'symbols_valid_meta']

# %%
info_ipod_data_df.to_sql(name='IPODataFull',con=engine,if_exists='append', index=False)

# %%
info_svm_data_df.to_sql(name='symbols_valid_meta',con=engine,if_exists='append', index=False)

# %%
pd.read_sql_query('SELECT * FROM "IPODataFull"', con=engine).head()
# Out:
#   Symbol                           Name             Sector  \
# 0      A     Agilent Technologies, Inc.      Capital Goods
# 1    AAC             AAC Holdings, Inc.        Health Care
# 2   AAOI  Applied Optoelectronics, Inc.         Technology
# 3    AAP         Advance Auto Parts Inc  Consumer Services
# 4    AAT    American Assets Trust, Inc.  Consumer Services
#
#                                            Industry             CEOName  \
# 0  Biotechnology: Laboratory Analytical Instruments    Michael McMullen
# 1                              Medical Specialities  Michael Cartwright
# 2                                    Semiconductors     Chih-Hsiang Lin
# 3                            Other Specialty Stores        Thomas Greco
# 4                     Real Estate Investment Trusts         Ernest Rady
#
#       PresidentName
# 0  Michael McMullen
# 1     Michael Nanko
# 2   Chih-Hsiang Lin
# 3      Thomas Greco
# 4       Ernest Rady

# %%
pd.read_sql_query('SELECT * FROM symbols_valid_meta', con=engine).head()
# Out:
#   Symbol Nasdaq Traded                                      Security Name  \
# 0      A             Y            Agilent Technologies, Inc. Common Stock
# 1     AA             Y                    Alcoa Corporation Common Stock
# 2   AAAU             Y                       Perth Mint Physical Gold ETF
# 3   AACG             Y  ATA Creativity Global - American Depositary Sh...
# 4   AADR             Y                AdvisorShares Dorsey Wright ADR ETF
#
#   CQS Symbol NASDAQ Symbol
# 0          A             A
# 1         AA            AA
# 2       AAAU          AAAU
# 3       None          AACG
# 4       AADR          AADR
